# %% [markdown]
# # MPA-MLF, Lab 6 - Feedforward Neural Networks with regularization techniques and hyperparameter tunning

# %% [markdown]
# ## Exercise 1 - Classification of an images

# %% [markdown]
# The goal of this task will be to create Multi-layer perceptron model, that is able to recognize the  CIFAR10 dataset (https://www.cs.toronto.edu/~kriz/cifar.html). The CIFAR10 dataset consist of 60000 images with resolution of 32x32 pixels. There are 10 classes in total - *airplane*, *automobile*, *bird*, *cat*, *deer*, *dog*, *frog*, *horse*, *ship*, *truck*

# %% [markdown]
# These is an example of the dataset:

# %% [markdown]
# ![cifar10.png](data:image/png;base64,...)

# %% [markdown]
# ### 0. Import libraries

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import SGD
from keras.datasets import cifar10
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import cv2

font = {'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)

# %% [markdown]
# ### 1. Load the Dataset
# The dataset is already a part of the Keras library, so we can quickly load it using the following command

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# The following numbered labels represent the labels in the dataset:

# %%
labels = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

# %% [markdown]
# ### 2. Data Examination

# %% [markdown]
# Fistly, lets have a look and the couple of images we have,

# %%
def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.array(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels_encoded = y_data[selected_ind]
  selected_labels = [labels[x[0]] for x in selected_labels_encoded]

  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img)

  for id_label, label in enumerate(selected_labels):
    plt.text((32/2) + 32*id_label - len(label), 32*(5/4), label)
  plt.axis('off')
  plt.show()

# %%
display_random_images(X_train, y_train)

# %%
#check the shape of image dataset

X_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# In our dataset, we have 60000 images with 32x32 resolution. Each image has three channels (R, G, B). We have 50000 images for training and 10000 images for testing. Each channel for each image has values from 0 - 255, where each number represents the pixel intensity.
# With the combination of intensities of R, G and B, you can display up to 16,777,216 different colours (256^3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here you can display each channel separately:

# %%
def display_channels_separately(image: np.array) -> None:

  plt.figure()
  fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(10, 5))


  axs[0].imshow(image[:,:,0],cmap='Reds')
  axs[1].imshow(image[:,:,1],cmap='Blues')
  axs[2].imshow(image[:,:,2],cmap='Greens')

  axs[3].imshow(image)

  plt.show()

# %%
display_channels_separately(X_train[0])

# %% [markdown]
# ### 3. Preprocessing of the images

# %% [markdown]
# For machine learning purposes, we have to preprocess our images. Firstly we need to scale our images, to scale intensity values from 0-1 (min-max scaling)

# %%
X_train_scaled = X_train.astype('float32') / 255.0

# %% [markdown]
# We need to one-hot-encode the labels in our ground truth variable as our second preprocessing.

# %%
y_train_encoded = to_categorical(y_train, num_classes=10)

# %% [markdown]
# ### 4. Define the model architecture

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# We will define *the Sequential* model as in our last exercise. This time we will use a different approach to determine the input layers. Instead of specifying the *input_dim* parameter in our first hidden layer, we will create a **Flatten** layer that takes our 32x32x3 image and reshapes it into 1x3072.
#
# We will specify ten neurons in our output layer because we have 10 possible outputs and a **softmax** activation function that returns us a probability distribution over the classes. The class with the highest probability is typically chosen as the predicted class for a given input.

# %% [markdown]
# Check the description of our model:

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       393,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 394,634 (1.51 MB)
#  Trainable params: 394,634 (1.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The next step is to compile our model, we will use *categorical_crossentropy* as a loss function, *stochastic gradient descend* as an optimisation and we will be checking *the accuracy* metric.

# %%
optimizer = SGD(learning_rate = 0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# ### 5. Train the model

# %% [markdown]
# Our model will be trained in the same way as in our last pc_labs,

# %%
history = model.fit(X_train_scaled, y_train_encoded, epochs=20, batch_size=128, validation_split = 0.2)
# Out:
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1149 - loss: 2.3211 - val_accuracy: 0.1531 - val_loss: 2.2874
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.1714 - loss: 2.2732 - val_accuracy: 0.1816 - val_loss: 2.2610
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.1940 - loss: 2.2484 - val_accuracy: 0.2088 - val_loss: 2.2378
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.2204 - loss: 2.2265 - val_accuracy: 0.2240 - val_loss: 2.2172
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.2352 - loss: 2.2068 - val_accuracy: 0.2434 - val_loss: 2.1989
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.2518 - loss: 2.1889 - val_accuracy: 0.2518 - val_loss: 2.1817
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.2610 - loss: 2.1726 - val_accuracy: 0.2571 - val_loss: 2.1664
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.2680 - loss: 2.1575 - val_accuracy: 0.2643 - val_loss: 2.1519
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.2727 - loss: 2.1435 - val_accuracy: 0.2686 - val_loss: 2.1391
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.2791 - loss: 2.1307 - val_accuracy: 0.2731 - val_loss: 2.1267
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.2844 - loss: 2.1187 - val_accuracy: 0.2755 - val_loss: 2.1152
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.2875 - loss: 2.1075 - val_accuracy: 0.2787 - val_loss: 2.1044
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.2910 - loss: 2.0971 - val_accuracy: 0.2807 - val_loss: 2.0944
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.2938 - loss: 2.0872 - val_accuracy: 0.2854 - val_loss: 2.0853
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.2971 - loss: 2.0780 - val_accuracy: 0.2858 - val_loss: 2.0763
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.3000 - loss: 2.0692 - val_accuracy: 0.2894 - val_loss: 2.0682
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.3022 - loss: 2.0609 - val_accuracy: 0.2908 - val_loss: 2.0602
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.3041 - loss: 2.0530 - val_accuracy: 0.2950 - val_loss: 2.0530
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.3077 - loss: 2.0455 - val_accuracy: 0.2976 - val_loss: 2.0461
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3086 - loss: 2.0385 - val_accuracy: 0.3005 - val_loss: 2.0390

# %% [markdown]
# ### 6. Model evaluation

# %%
X_test = X_test.astype('float32') / 255.0
y_test_encoded = to_categorical(y_test, num_classes=10)

# %%
score = model.evaluate(X_test, y_test_encoded, verbose=0)
print('Test loss:', score[0])
print(f'Test accuracy: {score[1]*100} %')
# Out:
# Test loss: 2.0357606410980225
# Test accuracy: 30.66999912261963 %

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %% [markdown]
# As you can see from the evaluation above, we was able to achive approx. 30% of an accuracy. In other word approx. 70% of an images we classified wrongly. That is really bad!

# %% [markdown]
# Lets check the best predictions from our model:

# %%
def show_the_best_predictions(model, x_test: np.array, y_test: np.array, n_of_pred: int = 10) -> None:
  mapping = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

  predictions = model.predict(x_test)
  y_test = y_test.reshape(1,-1)
  predictions_ind = np.argmax(predictions, axis=1)
  predictions_ind = predictions_ind.reshape(1, -1)

  corect_predictions = np.where(predictions_ind == y_test)

  rows_correct = corect_predictions[1]
  predictedtions_correct = predictions[rows_correct]
  target_correct = y_test[0][rows_correct]

  max_samples = predictions[rows_correct, target_correct]
  selected_images = x_test[rows_correct]
  sorted_ind = np.argsort(max_samples)[::-1]


  images = []
  prob = []
  labels = []


  for ind in range(n_of_pred):

    index = sorted_ind[ind]

    labels.append(target_correct[index])
    prob.append(max_samples[index])
    images.append(selected_images[index])

  plt.figure(figsize=(20,10))

  images = np.concatenate(np.asarray(images),axis=1)
  plt.imshow(images)
  for ins in range(n_of_pred):
    texts = '{}: \n{:.3f} %'.format(mapping[labels[ins]], prob[ins]*100)
    plt.text((32/2) + 32*ins - len(mapping[labels[ins]]), 32*(5/4), texts)

  plt.axis('off')
  plt.show()

# %%
show_the_best_predictions(model, X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %% [markdown]
# ### Task Description:

# %% [markdown]
# You task of this exercise would be to improve the model's performance to achieve better results in image classification task. There is no need to change the preprocessing of the dataset. There are possible way how to improve the models performance:

# %% [markdown]
# 1. Hyperparameter tunning - change the hyperparameters so that the model will perform better. You can experiment with the following:
#  - *changing the number of neurons in the hidden layer*
#  - *changing the number of hidden layers*
#  - *changing the activation functions*
#  - *changing the learning rate*
#  - *changing the optimizer* - So far, we have used only Gradient descend as our optimizer, but Keras offers other algorithms that can perform better - check the documentation!
#  - *changing the number of learning epochs*\
#  - *changing the batch size*
#
# 2. Regularization techniques - There are several regularization techniques that can improve the model's performance:
#  - *Dropout* -  In the Keras lib. you can add *dropout layer* into your Sequential model using the following command  *model.add(Dropout(p))* where *p* is an hyperparameter that controls dropout probabily, typical values are 0.1 - 0.5.
#  - *L1, L2 regularization* - In keras the regularization is applied for selected layers, there is an example how to add l2 regularization to an layer (for more details check the documnetation):  *model.add(Dense(64, activation='relu', input_dim=100, kernel_regularizer=l2(0.01)))*
#  - *Early stopping* -  In Keras, you can use the EarlyStopping callback to implement early stopping in your model. *early_stopping = EarlyStopping(monitor='val_loss', patience=3)*,  *model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val), callbacks=[early_stopping])*

# %% [markdown]
# Try to make the highest testing accuracy possible. You can directly edit the code that is presented above, or you can copy everything into new cells. Please submit only the code with the best performance and briefly describe what approaches you have tried and what were the results

# %% [markdown]
# ### WRITE YOUR DESCRIPTION IN THIS CELL ###

# %%
from keras.layers import Dropout
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import EarlyStopping

# %%
# =========================
# TEST DE PLUSIEURS MODELES
# =========================

results = []

def build_model(hidden_layers=[256], dropout_rate=0.0, activation='relu',
                optimizer_name='adam', learning_rate=0.001, l2_value=0.0):
    model = Sequential()
    model.add(Flatten(input_shape=(32, 32, 3)))

    for units in hidden_layers:
        model.add(Dense(units,
                        activation=activation,
                        kernel_regularizer=l2(l2_value)))
        if dropout_rate > 0:
            model.add(Dropout(dropout_rate))

    model.add(Dense(10, activation='softmax'))

    if optimizer_name == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    else:
        optimizer = SGD(learning_rate=learning_rate)

    model.compile(
        loss='categorical_crossentropy',
        optimizer=optimizer,
        metrics=['accuracy']
    )
    return model


experiments = [
    {
        "name": "Test 1 - baseline improved",
        "hidden_layers": [128],
        "dropout_rate": 0.0,
        "activation": "relu",
        "optimizer_name": "adam",
        "learning_rate": 0.001,
        "batch_size": 128,
        "epochs": 20,
        "l2_value": 0.0
    },
    {
        "name": "Test 2 - bigger network",
        "hidden_layers": [256, 128],
        "dropout_rate": 0.2,
        "activation": "relu",
        "optimizer_name": "adam",
        "learning_rate": 0.001,
        "batch_size": 128,
        "epochs": 25,
        "l2_value": 0.0
    },
    {
        "name": "Test 3 - dropout + L2",
        "hidden_layers": [512, 256],
        "dropout_rate": 0.3,
        "activation": "relu",
        "optimizer_name": "adam",
        "learning_rate": 0.001,
        "batch_size": 128,
        "epochs": 30,
        "l2_value": 0.0001
    },
    {
        "name": "Test 4 - smaller batch",
        "hidden_layers": [512, 256],
        "dropout_rate": 0.4,
        "activation": "relu",
        "optimizer_name": "adam",
        "learning_rate": 0.0005,
        "batch_size": 64,
        "epochs": 30,
        "l2_value": 0.0001
    },
    {
        "name": "Test 5 - SGD",
        "hidden_layers": [256, 128],
        "dropout_rate": 0.2,
        "activation": "relu",
        "optimizer_name": "sgd",
        "learning_rate": 0.01,
        "batch_size": 128,
        "epochs": 25,
        "l2_value": 0.0
    }
]

best_model = None
best_score = 0
best_history = None
best_config = None

for exp in experiments:
    print("=" * 60)
    print(exp["name"])

    model = build_model(
        hidden_layers=exp["hidden_layers"],
        dropout_rate=exp["dropout_rate"],
        activation=exp["activation"],
        optimizer_name=exp["optimizer_name"],
        learning_rate=exp["learning_rate"],
        l2_value=exp["l2_value"]
    )

    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True
    )

    history = model.fit(
        X_train_scaled,
        y_train_encoded,
        validation_split=0.2,
        epochs=exp["epochs"],
        batch_size=exp["batch_size"],
        callbacks=[early_stop],
        verbose=1
    )

    score = model.evaluate(X_test, y_test_encoded, verbose=0)
    test_acc = score[1]

    results.append((exp["name"], test_acc, exp))
    print(f"Test accuracy: {test_acc * 100:.2f}%")

    if test_acc > best_score:
        best_score = test_acc
        best_model = model
        best_history = history
        best_config = exp

print("\n" + "=" * 60)
print("BEST CONFIGURATION:")
print(best_config)
print(f"BEST TEST ACCURACY: {best_score * 100:.2f}%")
# Out:
# ============================================================
# Test 1 - baseline improved
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.3020 - loss: 1.9568 - val_accuracy: 0.3545 - val_loss: 1.8267
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.3694 - loss: 1.7869 - val_accuracy: 0.3589 - val_loss: 1.8123
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.3890 - loss: 1.7257 - val_accuracy: 0.3817 - val_loss: 1.7330
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.4049 - loss: 1.6832 - val_accuracy: 0.3892 - val_loss: 1.7230
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.4103 - loss: 1.6585 - val_accuracy: 0.3959 - val_loss: 1.7062
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.4255 - loss: 1.6195 - val_accuracy: 0.4080 - val_loss: 1.6817
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.4282 - loss: 1.6035 - val_accuracy: 0.4019 - val_loss: 1.6705
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4354 - loss: 1.5874 - val_accuracy: 0.4241 - val_loss: 1.6361
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4408 - loss: 1.5737 - val_accuracy: 0.4336 - val_loss: 1.6067
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.4473 - loss: 1.5565 - val_accuracy: 0.4232 - val_loss: 1.6397
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.4513 - loss: 1.5440 - val_accuracy: 0.4390 - val_loss: 1.5897
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4534 - loss: 1.5376 - val_accuracy: 0.4292 - val_loss: 1.6116
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4578 - loss: 1.5255 - val_accuracy: 0.4378 - val_loss: 1.5877
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4619 - loss: 1.5175 - val_accuracy: 0.4452 - val_loss: 1.5759
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4645 - loss: 1.5047 - val_accuracy: 0.4323 - val_loss: 1.5937
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.4709 - loss: 1.4933 - val_accuracy: 0.4458 - val_loss: 1.5823
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.4649 - loss: 1.5024 - val_accuracy: 0.4446 - val_loss: 1.5758
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.4737 - loss: 1.4853 - val_accuracy: 0.4411 - val_loss: 1.5836
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4762 - loss: 1.4760 - val_accuracy: 0.4357 - val_loss: 1.6046
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.4787 - loss: 1.4774 - val_accuracy: 0.4261 - val_loss: 1.6441
# Test accuracy: 45.28%
# ============================================================
# Test 2 - bigger network
# Epoch 1/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.2570 - loss: 2.0214 - val_accuracy: 0.3318 - val_loss: 1.8631
# Epoch 2/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.3243 - loss: 1.8661 - val_accuracy: 0.3611 - val_loss: 1.8125
# Epoch 3/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.3440 - loss: 1.8154 - val_accuracy: 0.3756 - val_loss: 1.7487
# Epoch 4/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.3595 - loss: 1.7789 - val_accuracy: 0.3970 - val_loss: 1.6978
# Epoch 5/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.3652 - loss: 1.7559 - val_accuracy: 0.4015 - val_loss: 1.6902
# Epoch 6/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.3719 - loss: 1.7332 - val_accuracy: 0.3990 - val_loss: 1.6801
# Epoch 7/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.3826 - loss: 1.7081 - val_accuracy: 0.4109 - val_loss: 1.6470
# Epoch 8/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.3887 - loss: 1.6966 - val_accuracy: 0.4153 - val_loss: 1.6411
# Epoch 9/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.3873 - loss: 1.6942 - val_accuracy: 0.4185 - val_loss: 1.6476
# Epoch 10/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.3957 - loss: 1.6737 - val_accuracy: 0.4197 - val_loss: 1.6333
# Epoch 11/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.4001 - loss: 1.6559 - val_accuracy: 0.4167 - val_loss: 1.6313
# Epoch 12/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.4038 - loss: 1.6522 - val_accuracy: 0.4246 - val_loss: 1.6112
# Epoch 13/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.4075 - loss: 1.6400 - val_accuracy: 0.4371 - val_loss: 1.5883
# Epoch 14/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.4123 - loss: 1.6321 - val_accuracy: 0.4389 - val_loss: 1.5790
# Epoch 15/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.4131 - loss: 1.6275 - val_accuracy: 0.4402 - val_loss: 1.5857
# Epoch 16/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.4124 - loss: 1.6220 - val_accuracy: 0.4359 - val_loss: 1.5838
# Epoch 17/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.4162 - loss: 1.6186 - val_accuracy: 0.4392 - val_loss: 1.5875
# Test accuracy: 44.77%
# ============================================================
# Test 3 - dropout + L2
# Epoch 1/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - accuracy: 0.2425 - loss: 2.1482 - val_accuracy: 0.3316 - val_loss: 1.9456
# Epoch 2/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 50ms/step - accuracy: 0.2973 - loss: 1.9747 - val_accuracy: 0.3356 - val_loss: 1.8886
# Epoch 3/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.3175 - loss: 1.9128 - val_accuracy: 0.3580 - val_loss: 1.8221
# Epoch 4/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - accuracy: 0.3291 - loss: 1.8653 - val_accuracy: 0.3653 - val_loss: 1.7973
# Epoch 5/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.3405 - loss: 1.8391 - val_accuracy: 0.3590 - val_loss: 1.7759
# Epoch 6/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.3475 - loss: 1.8120 - val_accuracy: 0.3632 - val_loss: 1.7860
# Epoch 7/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.3559 - loss: 1.7913 - val_accuracy: 0.3580 - val_loss: 1.8098
# Epoch 8/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - accuracy: 0.3537 - loss: 1.7950 - val_accuracy: 0.3976 - val_loss: 1.7341
# Epoch 9/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 53ms/step - accuracy: 0.3627 - loss: 1.7760 - val_accuracy: 0.4078 - val_loss: 1.7276
# Epoch 10/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - accuracy: 0.3701 - loss: 1.7517 - val_accuracy: 0.4038 - val_loss: 1.6962
# Epoch 11/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 50ms/step - accuracy: 0.3669 - loss: 1.7595 - val_accuracy: 0.4179 - val_loss: 1.6994
# Epoch 12/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 54ms/step - accuracy: 0.3710 - loss: 1.7545 - val_accuracy: 0.4142 - val_loss: 1.7211
# Epoch 13/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 50ms/step - accuracy: 0.3793 - loss: 1.7296 - val_accuracy: 0.4169 - val_loss: 1.6753
# Epoch 14/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 50ms/step - accuracy: 0.3853 - loss: 1.7211 - val_accuracy: 0.4237 - val_loss: 1.6773
# Epoch 15/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 50ms/step - accuracy: 0.3854 - loss: 1.7203 - val_accuracy: 0.4291 - val_loss: 1.6865
# Epoch 16/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.3857 - loss: 1.7150 - val_accuracy: 0.4278 - val_loss: 1.6870
# Test accuracy: 42.53%
# ============================================================
# Test 4 - smaller batch
# Epoch 1/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 27s 41ms/step - accuracy: 0.2300 - loss: 2.1663 - val_accuracy: 0.3126 - val_loss: 1.9726
# Epoch 2/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.2828 - loss: 2.0117 - val_accuracy: 0.3417 - val_loss: 1.9015
# Epoch 3/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.3068 - loss: 1.9373 - val_accuracy: 0.3593 - val_loss: 1.8422
# Epoch 4/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 45ms/step - accuracy: 0.3181 - loss: 1.8981 - val_accuracy: 0.3716 - val_loss: 1.8182
# Epoch 5/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.3269 - loss: 1.8639 - val_accuracy: 0.3766 - val_loss: 1.7940
# Epoch 6/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 38s 39ms/step - accuracy: 0.3363 - loss: 1.8326 - val_accuracy: 0.3797 - val_loss: 1.7763
# Epoch 7/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - accuracy: 0.3381 - loss: 1.8242 - val_accuracy: 0.3932 - val_loss: 1.7556
# Epoch 8/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 38ms/step - accuracy: 0.3479 - loss: 1.8077 - val_accuracy: 0.3828 - val_loss: 1.7718
# Epoch 9/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 38ms/step - accuracy: 0.3503 - loss: 1.7952 - val_accuracy: 0.3949 - val_loss: 1.7496
# Epoch 10/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 39ms/step - accuracy: 0.3576 - loss: 1.7829 - val_accuracy: 0.4085 - val_loss: 1.7349
# Epoch 11/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.3557 - loss: 1.7789 - val_accuracy: 0.4111 - val_loss: 1.7172
# Epoch 12/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - accuracy: 0.3600 - loss: 1.7716 - val_accuracy: 0.4033 - val_loss: 1.7448
# Epoch 13/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 42ms/step - accuracy: 0.3630 - loss: 1.7677 - val_accuracy: 0.4170 - val_loss: 1.7239
# Epoch 14/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 40ms/step - accuracy: 0.3641 - loss: 1.7643 - val_accuracy: 0.4126 - val_loss: 1.7345
# Test accuracy: 42.31%
# ============================================================
# Test 5 - SGD
# Epoch 1/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.2176 - loss: 2.1251 - val_accuracy: 0.3001 - val_loss: 1.9707
# Epoch 2/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.2959 - loss: 1.9525 - val_accuracy: 0.3364 - val_loss: 1.8790
# Epoch 3/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.3283 - loss: 1.8716 - val_accuracy: 0.3472 - val_loss: 1.8422
# Epoch 4/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.3456 - loss: 1.8272 - val_accuracy: 0.3700 - val_loss: 1.7811
# Epoch 5/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.3614 - loss: 1.7913 - val_accuracy: 0.3828 - val_loss: 1.7449
# Epoch 6/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.3734 - loss: 1.7627 - val_accuracy: 0.3864 - val_loss: 1.7289
# Epoch 7/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.3842 - loss: 1.7340 - val_accuracy: 0.4045 - val_loss: 1.6901
# Epoch 8/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.3901 - loss: 1.7162 - val_accuracy: 0.4093 - val_loss: 1.6793
# Epoch 9/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.3992 - loss: 1.6944 - val_accuracy: 0.4149 - val_loss: 1.6676
# Epoch 10/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.4017 - loss: 1.6773 - val_accuracy: 0.4142 - val_loss: 1.6507
# Epoch 11/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.4113 - loss: 1.6645 - val_accuracy: 0.4205 - val_loss: 1.6487
# Epoch 12/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4159 - loss: 1.6513 - val_accuracy: 0.4221 - val_loss: 1.6425
# Epoch 13/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.4214 - loss: 1.6342 - val_accuracy: 0.4252 - val_loss: 1.6206
# Epoch 14/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4250 - loss: 1.6245 - val_accuracy: 0.4299 - val_loss: 1.6163
# Epoch 15/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.4280 - loss: 1.6113 - val_accuracy: 0.4299 - val_loss: 1.6136
# Epoch 16/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4355 - loss: 1.5998 - val_accuracy: 0.4375 - val_loss: 1.5875
# Epoch 17/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.4385 - loss: 1.5843 - val_accuracy: 0.4298 - val_loss: 1.6012
# Epoch 18/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.4396 - loss: 1.5771 - val_accuracy: 0.4460 - val_loss: 1.5748
# Epoch 19/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.4441 - loss: 1.5662 - val_accuracy: 0.4500 - val_loss: 1.5584
# Epoch 20/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4484 - loss: 1.5592 - val_accuracy: 0.4627 - val_loss: 1.5481
# Epoch 21/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.4518 - loss: 1.5516 - val_accuracy: 0.4624 - val_loss: 1.5363
# Epoch 22/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4509 - loss: 1.5435 - val_accuracy: 0.4622 - val_loss: 1.5374
# Epoch 23/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.4568 - loss: 1.5336 - val_accuracy: 0.4506 - val_loss: 1.5465
# Epoch 24/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4575 - loss: 1.5247 - val_accuracy: 0.4714 - val_loss: 1.5165
# Epoch 25/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.4640 - loss: 1.5143 - val_accuracy: 0.4570 - val_loss: 1.5426
# Test accuracy: 48.21%
#
# ============================================================
# BEST CONFIGURATION:
# {'name': 'Test 5 - SGD', 'hidden_layers': [256, 128], 'dropout_rate': 0.2, 'activation': 'relu', 'optimizer_name': 'sgd', 'learning_rate': 0.01, 'batch_size': 128, 'epochs': 25, 'l2_value': 0.0}
# BEST TEST ACCURACY: 48.21%

# %%
print("Summary of experiments:\n")
for name, acc, config in results:
    print(f"{name} --> Test accuracy: {acc * 100:.2f}%")
# Out:
# Summary of experiments:
#
# Test 1 - baseline improved --> Test accuracy: 45.28%
# Test 2 - bigger network --> Test accuracy: 44.77%
# Test 3 - dropout + L2 --> Test accuracy: 42.53%
# Test 4 - smaller batch --> Test accuracy: 42.31%
# Test 5 - SGD --> Test accuracy: 48.21%

# %%
plt.figure()
plt.plot(best_history.history['loss'], label='train loss')
plt.plot(best_history.history['val_loss'], label='val loss')
plt.legend()
plt.title("Best model - Loss")
plt.show()

plt.figure()
plt.plot(best_history.history['accuracy'], label='train accuracy')
plt.plot(best_history.history['val_accuracy'], label='val accuracy')
plt.legend()
plt.title("Best model - Accuracy")
plt.show()

# %%
show_the_best_predictions(best_model, X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %% [markdown]
# ### Task Description
#
# I tried several approaches to improve the testing accuracy of the MLP model on CIFAR-10.
#
# First, I tested a baseline improved model with ReLU and Adam. Then, I increased the size of the network by adding more hidden layers and more neurons. I also tested regularization techniques such as dropout and L2 regularization, and I changed the batch size and learning rate.
#
# Finally, I compared Adam and SGD optimizers. Among all the tested configurations, the best result was obtained with a model using two hidden layers of 256 and 128 neurons, ReLU activation, dropout rate of 0.2, and SGD with a learning rate of 0.01.
#
# The best testing accuracy obtained was **48.21%**.
#
# Results of the experiments:
# - Test 1 - baseline improved: **45.28%**
# - Test 2 - bigger network: **44.77%**
# - Test 3 - dropout + L2: **42.53%**
# - Test 4 - smaller batch: **42.31%**
# - Test 5 - SGD: **48.21%**

# %% [markdown]
# ### FINAL CODE

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping

model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

optimizer = SGD(learning_rate=0.01)

model.compile(
    loss='categorical_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

history = model.fit(
    X_train_scaled,
    y_train_encoded,
    validation_split=0.2,
    epochs=25,
    batch_size=128,
    callbacks=[early_stop],
    verbose=1
)

score = model.evaluate(X_test, y_test_encoded, verbose=0)
print("Test loss:", score[0])
print(f"Test accuracy: {score[1] * 100:.2f}%")
# Out:
# Epoch 1/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.2281 - loss: 2.1131 - val_accuracy: 0.3082 - val_loss: 1.9575
# Epoch 2/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.2928 - loss: 1.9570 - val_accuracy: 0.3439 - val_loss: 1.8805
# Epoch 3/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.3246 - loss: 1.8845 - val_accuracy: 0.3563 - val_loss: 1.8224
# Epoch 4/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.3430 - loss: 1.8367 - val_accuracy: 0.3799 - val_loss: 1.7792
# Epoch 5/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.3620 - loss: 1.7959 - val_accuracy: 0.3905 - val_loss: 1.7487
# Epoch 6/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.3732 - loss: 1.7669 - val_accuracy: 0.4003 - val_loss: 1.7278
# Epoch 7/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.3828 - loss: 1.7372 - val_accuracy: 0.3990 - val_loss: 1.7165
# Epoch 8/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.3889 - loss: 1.7199 - val_accuracy: 0.4115 - val_loss: 1.6851
# Epoch 9/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.3989 - loss: 1.6970 - val_accuracy: 0.4110 - val_loss: 1.6789
# Epoch 10/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4061 - loss: 1.6795 - val_accuracy: 0.4213 - val_loss: 1.6666
# Epoch 11/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.4109 - loss: 1.6621 - val_accuracy: 0.4219 - val_loss: 1.6396
# Epoch 12/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4197 - loss: 1.6435 - val_accuracy: 0.4312 - val_loss: 1.6240
# Epoch 13/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4238 - loss: 1.6299 - val_accuracy: 0.4290 - val_loss: 1.6133
# Epoch 14/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4261 - loss: 1.6161 - val_accuracy: 0.4465 - val_loss: 1.5868
# Epoch 15/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4297 - loss: 1.6053 - val_accuracy: 0.4431 - val_loss: 1.5904
# Epoch 16/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.4362 - loss: 1.5937 - val_accuracy: 0.4357 - val_loss: 1.5964
# Epoch 17/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4401 - loss: 1.5812 - val_accuracy: 0.4522 - val_loss: 1.5646
# Epoch 18/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4417 - loss: 1.5740 - val_accuracy: 0.4509 - val_loss: 1.5709
# Epoch 19/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4460 - loss: 1.5632 - val_accuracy: 0.4474 - val_loss: 1.5577
# Epoch 20/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4516 - loss: 1.5527 - val_accuracy: 0.4368 - val_loss: 1.6035
# Epoch 21/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4556 - loss: 1.5401 - val_accuracy: 0.4636 - val_loss: 1.5220
# Epoch 22/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4590 - loss: 1.5355 - val_accuracy: 0.4611 - val_loss: 1.5235
# Epoch 23/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.4613 - loss: 1.5274 - val_accuracy: 0.4630 - val_loss: 1.5308
# Epoch 24/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.4642 - loss: 1.5133 - val_accuracy: 0.4622 - val_loss: 1.5347
# Test loss: 1.4973185062408447
# Test accuracy: 47.04%

# %% [markdown]
# ### Voluntary task:
# Implement one of the hyperparameter tunning algorithms discussed in the lecture, such as *Grid Search*, *Random Search* or more sophisticated ones. Some of these algorithms are already included in the Keras. Check the documentation
